# %% [markdown]
# # E02 S01 causal DAG review
#
# This notebook is a thin review surface over the authoritative deterministic generator in `analysis/causal_model.py`. It does not execute simulator transitions or begin S02.

# %%
from analysis.causal_model import registry, validate_design
design = registry()
validation = validate_design(design)
validation['success'], validation['counts']

# %% [markdown]
# ## Review rules
#
# - Primary estimands randomize or fix explicit factors.
# - Only baseline pairing blocks enter adjustment sets.
# - Post-treatment observations, opportunities, failures, retries, proposals, actions, trajectories, costs, and terminal class are not adjusted for.
# - The E01 global traditional controller remains a descriptive bundled comparator.
# - Exact central-local versus distributed parity is the S02 hard gate.
